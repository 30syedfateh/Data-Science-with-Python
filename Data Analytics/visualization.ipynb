# %% [markdown]
# VISUALIZATION
# - FIGURE
# -axes
# -plot
# -pie
# -bar
# -scatter
# -

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
 y = [21,345,56,12,5,47,1]
 plt.plot(y)

# %%
plt.figure(figsize=(15,4))
plt.pie(y)
plt.show()

# %%
fig,ax = plt.subplots(nrows=1, ncols =2)
plt.show()

# %%
t = np.arange(-3 * np.pi, 3 * np.pi, 0.2)
x = np.sin(t)
y = np.cos(t)
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15,2))
ax[0].plot(t,x,'r')
ax[1].bar(t,y)
plt.show()

# %%
x = [100,200,300,400,500,600,700,800,900,1000]
y = [23,45,67,89,90,34,6,7,8,2]
plt.plot(x,y,'go--',linewidth=2, color ='purple',marker='s',markersize=10,markerfacecolor='red',linestyle='--')
# Out:
# C:\Users\abbas\AppData\Local\Temp\ipykernel_14564\1189005226.py:3: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "go--" (-> linestyle='--'). The keyword argument will take precedence.
#   plt.plot(x,y,'go--',linewidth=2, color ='purple',marker='s',markersize=10,markerfacecolor='red',linestyle='--')
# C:\Users\abbas\AppData\Local\Temp\ipykernel_14564\1189005226.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "go--" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x,y,'go--',linewidth=2, color ='purple',marker='s',markersize=10,markerfacecolor='red',linestyle='--')
# C:\Users\abbas\AppData\Local\Temp\ipykernel_14564\1189005226.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
# ...

# %%
plt.plot?
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...

# %%
plt.pie?
# Out:
# Signature:
# plt.pie(
#     x,
#     explode=None,
#     labels=None,
#     colors=None,
#     autopct=None,
#     pctdistance=0.6,
#     shadow=False,
#     labeldistance=1.1,
#     startangle=0,
#     radius=1,
#     counterclock=True,
#     wedgeprops=None,
#     textprops=None,
#     center=(0, 0),
#     frame=False,
#     rotatelabels=False,
#     *,
#     normalize=True,
#     data=None,
# )
# Docstring:
# Plot a pie chart.
#
# Make a pie chart of array *x*.  The fractional area of each wedge is
# given by ``x/sum(x)``.
#
# The wedges are plotted counterclockwise, by default starting from the
# x-axis.
#
# Parameters
# ----------
# x : 1D array-like
#     The wedge sizes.
#
# explode : array-like, default: None
#     If not *None*, is a ``len(x)`` array which specifies the fraction
#     of the radius with which to offset each wedge.
#
# labels : list, default: None
#     A sequence of strings providing the labels for each wedge
#
# colors : array-like, default: None
# ...

# %%
plt.plot(x,y)
plt.title()
plt.xlabel()
plt.ylabel()
fontdict={'color':'red'}
plt.text(800,60,"This is \n serious")
plt.annotate()
arrowprops = dict
